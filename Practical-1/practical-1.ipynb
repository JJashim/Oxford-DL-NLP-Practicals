# %% [markdown]
# ## Practical 1: word2vec
# <p>Oxford CS - Deep NLP 2017<br>
# https://www.cs.ox.ac.uk/teaching/courses/2016-2017/dl/</p>
# <p>[Yannis Assael, Brendan Shillingford, Chris Dyer]</p>

# %% [markdown]
# This practical is presented as an IPython Notebook, with the code written for recent versions of **Python 3**. The code in this practical will not work with Python 2 unless you modify it. If you are using your own Python installation, ensure you have a setup identical to that described in the installation shell script (which is intended for use with the department lab machines). We will be unable to support installation on personal machines due to time constraints, so please use the lab machines and the setup script if you are unfamiliar with how to install Anaconda.
#
# To execute a notebook cell, press `shift-enter`. The return value of the last command will be displayed, if it is not `None`.
#
# Potentially useful library documentation, references, and resources:
#
# * IPython notebooks: <https://ipython.org/ipython-doc/3/notebook/notebook.html#introduction>
# * Numpy numerical array library: <https://docs.scipy.org/doc/>
# * Gensim's word2vec: <https://radimrehurek.com/gensim/models/word2vec.html>
# * Bokeh interactive plots: <http://bokeh.pydata.org/en/latest/> (we provide plotting code here, but click the thumbnails for more examples to copy-paste)
# * scikit-learn ML library (aka `sklearn`): <http://scikit-learn.org/stable/documentation.html>
# * nltk NLP toolkit: <http://www.nltk.org/>
# * tutorial for processing xml in python using `lxml`: <http://lxml.de/tutorial.html> (we did this for you below, but in case you need it in the future)

# %%
import numpy as np
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe5a2d88-7f54-4087-ab2d-8bbab71c2f57">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Part 0: Download the TED dataset

# %%
import urllib.request
import zipfile
import lxml.etree

# %%
# Download the dataset if it's not already there: this may take a minute as it is 75MB
if not os.path.isfile('ted_en-20160408.zip'):
    urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")

# %%
# For now, we're only interested in the subtitle text, so let's extract that from the XML:
with zipfile.ZipFile('ted_en-20160408.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))
input_text = '\n'.join(doc.xpath('//content/text()'))
del doc

# %% [markdown]
# ### Part 1: Preprocessing
#
# In this part, we attempt to clean up the raw subtitles a bit, so that we get only sentences. The following substring shows examples of what we're trying to get rid of. Since it's hard to define precisely what we want to get rid of, we'll just use some simple heuristics.

# %%
i = input_text.find("Hyowon Gweon: See this?")
input_text[i-20:i+150]
# Out:
# ' baby does.\n(Video) Hyowon Gweon: See this? (Ball squeaks) Did you see that? (Ball squeaks) Cool. See this one? (Ball squeaks) Wow.\nLaura Schulz: Told you. (Laughs)\n(Vide'

# %% [markdown]
# Let's start by removing all parenthesized strings using a regex:

# %%
input_text_noparens = re.sub(r'\([^)]*\)', '', input_text)

# %% [markdown]
# We can verify the same location in the text is now clean as follows. We won't worry about the irregular spaces since we'll later split the text into sentences and tokenize it anyway.

# %%
i = input_text_noparens.find("Hyowon Gweon: See this?")
input_text_noparens[i-20:i+150]
# Out:
# "hat the baby does.\n Hyowon Gweon: See this?  Did you see that?  Cool. See this one?  Wow.\nLaura Schulz: Told you. \n HG: See this one?  Hey Clara, this one's for you. You "

# %% [markdown]
# Now, let's attempt to remove speakers' names that occur at the beginning of a line, by deleting pieces of the form "`<up to 20 characters>:`", as shown in this example. Of course, this is an imperfect heuristic.

# %%
sentences_strings_ted = []
for line in input_text_noparens.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)

# Uncomment if you need to save some RAM: these strings are about 50MB.
# del input_text, input_text_noparens

# Let's view the first few:
sentences_strings_ted[:5]
# Out:
# ["Here are two reasons companies fail: they only do more of the same, or they only do what's new",
#  'To me the real, real solution to quality growth is figuring out the balance between two activities: exploration and exploitation',
#  ' Both are necessary, but it can be too much of a good thing',
#  'Consider Facit',
#  " I'm actually old enough to remember them"]

# %% [markdown]
# Now that we have sentences, we're ready to tokenize each of them into words. This tokenization is imperfect, of course. For instance, how many tokens is "can't", and where/how do we split it? We'll take the simplest naive approach of splitting on spaces. Before splitting, we remove non-alphanumeric characters, such as punctuation. You may want to consider the following question: why do we replace these characters with spaces rather than deleting them? Think of a case where this yields a different answer.

# %%
sentences_ted = []
for sent_str in sentences_strings_ted:
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    sentences_ted.append(tokens)

# %% [markdown]
# Two sample processed sentences:

# %%
len(sentences_ted)
# Out:
# 266694

# %%
print(sentences_ted[0])
# Out:
# ['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new']

# %% [markdown]
# ### Part 2: Word Frequencies

# %% [markdown]
# If you store the counts of the top 1000 words in a list called `counts_ted_top1000`, the code below will plot the histogram requested in the writeup.

# %%
words = [word for sentence in sentences_ted for word in sentence] 
uni_word = set(words)
len_words = [0]*len(uni_word)
d = dict(zip(uni_word,len_words))
for word in words:
    d[word] += 1

# %%
import operator
ted_top1000 = [(i,j) for i,j in sorted(d.items(),key=operator.itemgetter(1),reverse=True)[:1000]]
counts_ted_top1000, ted_top1000_words = zip(*ted_top1000) 
print(counts_ted_top1000[:5], ted_top1000_words[:5])
counts_ted_top1000 = []
ted_top1000_words = []
for i in ted_top1000:
    counts_ted_top1000.append(i[1])
    ted_top1000_words.append(i[0])
print(counts_ted_top1000[:5], ted_top1000_words[:5])
# Out:
# ('the', 'and', 'to', 'of', 'a') (207748, 149305, 125169, 114818, 105399)
# [207748, 149305, 125169, 114818, 105399] ['the', 'and', 'to', 'of', 'a']

# %% [markdown]
# Plot distribution of top-1000 words

# %%
hist, edges = np.histogram(counts_ted_top1000, density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7c590733-4a0a-4447-aff7-d00dd8cc2538"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7c590733-4a0a-4447-aff7-d00dd8cc2538");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7c590733-4a0a-4447-aff7-d00dd8cc2538");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7c590733-4a0a-4447-aff7-d00dd8cc2538' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"54a6eba2-2ff8-422a-bd9e-980a17dc9a6b":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"4ab5f188-19c0-4d3b-8cd2-7cf3f3bf9696","type":"Quad"},{"attributes":{},"id":"639515d0-61e9-4493-8670-a05608ae8f5a","type":"SaveTool"},{"attributes":{"plot":null,"text":"Top-1000 words distribution"},"id":"5b20ffdf-d180-420a-8250-351295ea7f4c","type":"Title"},{"attributes":{"plot":{"id":"53e9e03d-edc6-4e6e-80f3-18327065cf16","subtype":"Figure","type":"Plot"},"ticker":{"id":"87f73c5d-a467-46c1-be5f-21fc29c33362","type":"BasicTicker"}},"id":"2ab1de2e-4dcc-45d2-ac83-724e86abd0ef","type":"Grid"},{"attributes":{},"id":"80ba8852-0854-4b8f-b3ca-be921eecf782","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"22fd922e-7bb9-4c20-83d4-6bed7af9e2df","type":"BasicTickFormatter"},"plot":{"id":"53e9e03d-edc6-4e6e-80f3-18327065cf16","subtype":"Figure","type":"Plot"},"ticker":{"id":"87f73c5d-a467-46c1-be5f-21fc29c33362","type":"BasicTicker"}},"id":"d30c85c1-0201-4abf-bc67-fee67688c1c3","type":"LinearAxis"},{"attributes":{},"id":"c63ff348-d68e-45d9-82dc-e052a47ad8ae","type":"LinearScale"},{"attributes":{"callback":null},"id":"4fdde428-7e8c-449f-a448-0189c07d49b4","type":"DataRange1d"},{"attributes":{},"id":"65370c1a-d80f-44cf-b98c-218e8a5a9ea8","type":"LinearScale"},{"attributes":{},"id":"776cdeb0-f252-4c07-9914-72c89c189238","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"9adf7681-94be-4ccc-b892-604cbfeb8471","type":"DataRange1d"},{"attributes":{},"id":"22fd922e-7bb9-4c20-83d4-6bed7af9e2df","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f3922e52-0635-4a7a-b09c-9cd248b67f73","type":"Quad"},{"attributes":{},"id":"87f73c5d-a467-46c1-be5f-21fc29c33362","type":"BasicTicker"},{"attributes":{"data_source":{"id":"92abd883-1c59-4fc2-bfe4-96656a4ebcef","type":"ColumnDataSource"},"glyph":{"id":"4ab5f188-19c0-4d3b-8cd2-7cf3f3bf9696","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f3922e52-0635-4a7a-b09c-9cd248b67f73","type":"Quad"},"selection_glyph":null,"view":{"id":"fa2cf495-d335-4fb5-9244-97b9579c7490","type":"CDSView"}},"id":"ac470abb-bff1-4707-b153-75b2ccd1d368","type":"GlyphRenderer"},{"attributes":{"source":{"id":"92abd883-1c59-4fc2-bfe4-96656a4ebcef","type":"ColumnDataSource"}},"id":"fa2cf495-d335-4fb5-9244-97b9579c7490","type":"CDSView"},{"attributes":{"formatter":{"id":"80ba8852-0854-4b8f-b3ca-be921eecf782","type":"BasicTickFormatter"},"plot":{"id":"53e9e03d-edc6-4e6e-80f3-18327065cf16","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3bb8e63-26cb-4eac-9111-5c879a93d9ab","type":"BasicTicker"}},"id":"7d33d881-1f3e-4566-a7ca-91a1979f03df","type":"LinearAxis"},{"attributes":{"below":[{"id":"d30c85c1-0201-4abf-bc67-fee67688c1c3","type":"LinearAxis"}],"left":[{"id":"7d33d881-1f3e-4566-a7ca-91a1979f03df","type":"LinearAxis"}],"renderers":[{"id":"d30c85c1-0201-4abf-bc67-fee67688c1c3","type":"LinearAxis"},{"id":"2ab1de2e-4dcc-45d2-ac83-724e86abd0ef","type":"Grid"},{"id":"7d33d881-1f3e-4566-a7ca-91a1979f03df","type":"LinearAxis"},{"id":"bb227c38-c274-4ac9-99b9-5f349e71f174","type":"Grid"},{"id":"ac470abb-bff1-4707-b153-75b2ccd1d368","type":"GlyphRenderer"}],"title":{"id":"5b20ffdf-d180-420a-8250-351295ea7f4c","type":"Title"},"toolbar":{"id":"7fa7e89f-6aa2-4a4a-8d93-3c7a004e39b9","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"4fdde428-7e8c-449f-a448-0189c07d49b4","type":"DataRange1d"},"x_scale":{"id":"c63ff348-d68e-45d9-82dc-e052a47ad8ae","type":"LinearScale"},"y_range":{"id":"9adf7681-94be-4ccc-b892-604cbfeb8471","type":"DataRange1d"},"y_scale":{"id":"65370c1a-d80f-44cf-b98c-218e8a5a9ea8","type":"Lin ...

# %% [markdown]
# ### Part 3: Train Word2Vec

# %%
model_ted = Word2Vec(sentences_ted, size=100, window=5, min_count=5, workers=4)
model_ted.wv.most_similar_cosmul(positive=['electronic','calculator'],negative=['calculators'])
model_ted.wv.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'

# %% [markdown]
# ### Part 4: Ted Learnt Representations

# %% [markdown]
# Finding similar words: (see gensim docs for more functionality of `most_similar`)

# %%
model_ted.most_similar("man")
len(model_ted.wv.vocab)
# Out:
# 21444

# %%
model_ted.most_similar("computer")
# Out:
# [('software', 0.7360825538635254),
#  ('machine', 0.7145148515701294),
#  ('robot', 0.7077524065971375),
#  ('device', 0.6820636987686157),
#  ('interface', 0.6705887913703918),
#  ('3d', 0.6595069169998169),
#  ('camera', 0.6488672494888306),
#  ('chip', 0.6447008848190308),
#  ('program', 0.6408616304397583),
#  ('video', 0.6227238774299622)]

# %%
words_top_ted = []
words_top_ted = ted_top1000_words
words_top_ted[:5]
len(model_ted['the'])
# Out:
# 100

# %% [markdown]
# #### t-SNE visualization
# To use the t-SNE code below, first put a list of the top 1000 words (as strings) into a variable `words_top_ted`. The following code gets the corresponding vectors from the model, assuming it's called `model_ted`:

# %%
# This assumes words_top_ted is a list of strings, the top 1000 words
words_top_vec_ted = []
words_top_vec_ted = model_ted[words_top_ted]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words of TED")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="625ed6d5-38ac-42fb-ae4b-890740ba6852"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("625ed6d5-38ac-42fb-ae4b-890740ba6852");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("625ed6d5-38ac-42fb-ae4b-890740ba6852");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '625ed6d5-38ac-42fb-ae4b-890740ba6852' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c9b2ae64-63b0-4267-887e-405456f53480":{"roots":{"references":[{"attributes":{},"id":"1363588a-cde6-497b-abad-0560bfaccd0e","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words of TED"},"id":"fcad0057-c019-4dcf-9901-b25d8b05dae0","type":"Title"},{"attributes":{"callback":null},"id":"24fe9d43-8ecc-4336-ab80-603d0e64226e","type":"DataRange1d"},{"attributes":{},"id":"60dc0624-c209-4961-81ae-58c4e9adc1bd","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"98f2cedb-9f2f-4652-8230-02dfffdbb6d4","type":"PanTool"},{"id":"1363588a-cde6-497b-abad-0560bfaccd0e","type":"WheelZoomTool"},{"id":"60dc0624-c209-4961-81ae-58c4e9adc1bd","type":"ResetTool"},{"id":"0bf25d0d-24ac-4b26-b521-e9f1b8ff6e16","type":"SaveTool"}]},"id":"aaafb553-a99b-4445-bc71-867b339ee977","type":"Toolbar"},{"attributes":{},"id":"0bf25d0d-24ac-4b26-b521-e9f1b8ff6e16","type":"SaveTool"},{"attributes":{},"id":"37105a24-5058-4959-84d0-993a35922755","type":"LinearScale"},{"attributes":{"callback":null},"id":"c63d4beb-e645-4b7b-a97c-5806e92d09fc","type":"DataRange1d"},{"attributes":{},"id":"1297be5d-61a0-4e5b-b3ae-9fc6e5edd1cf","type":"LinearScale"},{"attributes":{},"id":"c20bcde6-a0a6-4a95-81bf-59431c313445","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2a7d6a33-4df2-4c35-ac33-eb5bdb4f9da3","subtype":"Figure","type":"Plot"},"ticker":{"id":"beca975c-ea21-4c70-939f-a0507287fbe5","type":"BasicTicker"}},"id":"911d8754-d2fd-4a0e-ada9-757c325dd314","type":"Grid"},{"attributes":{"formatter":{"id":"14e95128-e09a-415e-aabd-f941f519d3cc","type":"BasicTickFormatter"},"plot":{"id":"2a7d6a33-4df2-4c35-ac33-eb5bdb4f9da3","subtype":"Figure","type":"Plot"},"ticker":{"id":"beca975c-ea21-4c70-939f-a0507287fbe5","type":"BasicTicker"}},"id":"254a60e7-757e-4a96-8483-ae5b392be8f7","type":"LinearAxis"},{"attributes":{},"id":"beca975c-ea21-4c70-939f-a0507287fbe5","type":"BasicTicker"},{"attributes":{"formatter":{"id":"c20bcde6-a0a6-4a95-81bf-59431c313445","type":"BasicTickFormatter"},"plot":{"id":"2a7d6a33-4df2-4c35-ac33-eb5bdb4f9da3","subtype":"Figure","type":"Plot"},"ticker":{"id":"6566a125-9a4c-461f-89a0-a0a215c6e14f","type":"BasicTicker"}},"id":"e0572253-2b21-43dd-94a7-5077ebf54e7e","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"32fdcf7b-fcfc-4b6c-8614-fece8be3acd9","type":"Circle"},{"attributes":{},"id":"6566a125-9a4c-461f-89a0-a0a215c6e14f","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"77986d76-e24e-46aa-8303-1bf4e24d2283","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"2a7d6a33-4df2-4c35-ac33-eb5bdb4f9da3","subtype":"Figure","type":"Plot"},"ticker":{"id":"6566a125-9a4c-461f-89a0-a0a215c6e14f","type":"BasicTicker"}},"id":"8ae99bb8-a1f2-4aef-86d4-77f9b61dbac9","type":"Grid"},{"attributes":{"plot":{"id":"2a7d6a33-4df2-4c35-ac33-eb5bdb4f9da3","subtype":"Figure","type":"Plot"},"source":{"id":"699518dc-d292-4634-b296-8bc7984fb779","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"5f1f41d7-dc66-48ce-b8a2-32be9fcabe3c","type":"LabelSet"},{"attributes":{},"id":"14e95128-e09a-415e-aabd-f941f519d3cc","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"699518dc-d292-4634-b296-8bc7984fb779","type":"ColumnDataSource"},"glyph":{"id":"77986d76-e24e-46aa-8303-1bf4e24d2283","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"32fdcf7b-fcfc-4b6c-8614-fece8be3acd9","type":"Circle"},"selection_glyph":null,"view": ...

# %%
#Cannot display Bokeh Images (dynamic content) in github.
from IPython.display import Image
Image('tsne_TED.png')

# %% [markdown]
# ### Part 5: Wiki Learnt Representations

# %% [markdown]
# Download dataset

# %%
if not os.path.isfile('wikitext-103-raw-v1.zip'):
    urllib.request.urlretrieve("https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-103-raw-v1.zip", filename="wikitext-103-raw-v1.zip")

# %%
with zipfile.ZipFile('wikitext-103-raw-v1.zip', 'r') as z:
    input_text = str(z.open('wikitext-103-raw/wiki.train.raw', 'r').read(), encoding='utf-8') # Thanks Robert Bastian

# %% [markdown]
# Preprocess sentences (note that it's important to remove small sentences for performance)

# %%
sentences_wiki = []
for line in input_text.split('\n'):
    s = [x for x in line.split('.') if x and len(x.split()) >= 5]
    sentences_wiki.extend(s)
    
for s_i in range(len(sentences_wiki)):
    sentences_wiki[s_i] = re.sub("[^a-z]", " ", sentences_wiki[s_i].lower())
    sentences_wiki[s_i] = re.sub(r'\([^)]*\)', '', sentences_wiki[s_i])
del input_text

# %%
# sample 1/5 of the data
shuffle(sentences_wiki)
print('Length before split:',len(sentences_wiki))
sentences_wiki = sentences_wiki[:int(len(sentences_wiki)//5)]
print('Length after split:',len(sentences_wiki))
# Out:
# Length before split: 235440
# Length after split: 47088

# %%
crop_sentences_wiki = []
for sent_str in sentences_wiki:
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    crop_sentences_wiki.append(tokens)
#crop_sentences_wiki[:100]

# %% [markdown]
# Now, repeat all the same steps that you performed above. You should be able to reuse essentially all the code.

# %%
import collections
count_wiki = collections.Counter()
for sentence in sentences_wiki:
    for word in sentence.split(' '):
        count_wiki[word] += 1

words_top_wiki = [x[0] for x in count_wiki.most_common() if len(x[0]) > 1]
words_top_wiki = words_top_wiki[:1000]

# %%
model_wiki = Word2Vec(sentences=crop_sentences_wiki, size=100, window=5, min_count=5, workers=4)

# %% [markdown]
# #### t-SNE visualization

# %%
# This assumes words_top_wiki is a list of strings, the top 1000 words
words_top_vec_wiki = model_wiki[words_top_wiki]

tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="439e8823-a5fc-4d59-84c4-21955171ebc6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("439e8823-a5fc-4d59-84c4-21955171ebc6");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("439e8823-a5fc-4d59-84c4-21955171ebc6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '439e8823-a5fc-4d59-84c4-21955171ebc6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c7caf9c2-87cf-423b-b5bc-b20b852d1ed2":{"roots":{"references":[{"attributes":{"formatter":{"id":"815cea96-e163-4a53-b483-8a925c643978","type":"BasicTickFormatter"},"plot":{"id":"be64bc08-444f-4b0d-a514-319f048af817","subtype":"Figure","type":"Plot"},"ticker":{"id":"dac099b8-2452-499d-be03-da3fdbcdff31","type":"BasicTicker"}},"id":"8bdce89d-c2f4-4d95-8970-f76cec76af6e","type":"LinearAxis"},{"attributes":{},"id":"dac099b8-2452-499d-be03-da3fdbcdff31","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"be64bc08-444f-4b0d-a514-319f048af817","subtype":"Figure","type":"Plot"},"ticker":{"id":"dac099b8-2452-499d-be03-da3fdbcdff31","type":"BasicTicker"}},"id":"eac79f02-24a6-4f28-94eb-de83c645aa54","type":"Grid"},{"attributes":{"plot":{"id":"be64bc08-444f-4b0d-a514-319f048af817","subtype":"Figure","type":"Plot"},"source":{"id":"3509acec-b355-4cb6-9be0-e7a44f4a5ba7","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"25578f78-e712-4928-8dd5-3e744413a520","type":"LabelSet"},{"attributes":{},"id":"7766ea6e-508d-418b-b6dc-b8b237b20204","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"b33fdaa4-a37c-46b5-ab4d-6d8f8991073b","type":"LinearAxis"}],"left":[{"id":"8bdce89d-c2f4-4d95-8970-f76cec76af6e","type":"LinearAxis"}],"renderers":[{"id":"b33fdaa4-a37c-46b5-ab4d-6d8f8991073b","type":"LinearAxis"},{"id":"9858cc02-8f68-4ba6-9ca7-f9663502348a","type":"Grid"},{"id":"8bdce89d-c2f4-4d95-8970-f76cec76af6e","type":"LinearAxis"},{"id":"eac79f02-24a6-4f28-94eb-de83c645aa54","type":"Grid"},{"id":"f8dd6c06-2cbc-4ece-b1fb-95e4286378a6","type":"GlyphRenderer"},{"id":"25578f78-e712-4928-8dd5-3e744413a520","type":"LabelSet"}],"title":{"id":"e9b838b4-d374-4d08-aa64-e810d1ec5e3c","type":"Title"},"toolbar":{"id":"5e3c9d66-628e-4803-88e3-9ce3bed1fb40","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"7eb85356-75c7-4634-9226-e5d1285973e6","type":"DataRange1d"},"x_scale":{"id":"5ebbf142-dc00-4a5d-a1e7-bfd1e40a88ae","type":"LinearScale"},"y_range":{"id":"dd89be72-7b57-48f4-9143-61667685769b","type":"DataRange1d"},"y_scale":{"id":"eb4a1d83-4aed-45c7-9245-59114be07f5d","type":"LinearScale"}},"id":"be64bc08-444f-4b0d-a514-319f048af817","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x1","x2","names"],"data":{"names":["the","and","to","of","that","in","it","we","you","is","this","so","they","was","for","have","are","what","but","on","with","can","about","there","be","as","at","all","not","do","one","my","re","people","like","if","from","our","now","just","or","these","he","an","when","because","by","out","me","going","how","very","up","them","know","had","more","think","your","which","would","see","were","their","ve","who","then","really","get","here","us","world","time","some","has","way","into","don","actually","will","where","other","things","could","years","want","go","make","well","been","no","right","something","first","said","than","she","those","two","thing","also","little","got","most","say","look","much","his","new","over","even","life","back","work","only","did","take","need","many","lot","every","why","around","kind","through","laughter","down","ll","different","good","being","same","her","year","come","let","three","use","day","doing","put","called","made","today","after","any","tell","percent","human","change","find","great","started","own","before","another","talk","fact","thought","better","didn","its","last","idea","might","never","still","went","next","should","important","give","problem","part","big","off","start","each","came","system","show","story","long","again","course","between","together","him","brain","water","bit","able","few","ago","used","women","too","does","mean","whole","end","technology","found","question","example","looking","maybe","ever","wanted","love","data","old","place","always", ...

# %%
from IPython.display import Image
Image('tsne_Wiki.png')
